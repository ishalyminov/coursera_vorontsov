# %%
from collections import defaultdict
from operator import itemgetter

import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv('titanic.csv')

# %%
del df['PassengerId']
del df['Name']
del df['SibSp']
del df['Parch']
del df['Ticket']
del df['Cabin']
del df['Embarked']

# %%
df
# Out:
#      Survived  Pclass     Sex   Age      Fare
# 0           0       3    male  22.0    7.2500
# 1           1       1  female  38.0   71.2833
# 2           1       3  female  26.0    7.9250
# 3           1       1  female  35.0   53.1000
# 4           0       3    male  35.0    8.0500
# 5           0       3    male   NaN    8.4583
# 6           0       1    male  54.0   51.8625
# 7           0       3    male   2.0   21.0750
# 8           1       3  female  27.0   11.1333
# 9           1       2  female  14.0   30.0708
# 10          1       3  female   4.0   16.7000
# 11          1       1  female  58.0   26.5500
# 12          0       3    male  20.0    8.0500
# 13          0       3    male  39.0   31.2750
# 14          0       3  female  14.0    7.8542
# 15          1       2  female  55.0   16.0000
# 16          0       3    male   2.0   29.1250
# 17          1       2    male   NaN   13.0000
# 18          0       3  female  31.0   18.0000
# ...

# %%
df = df[np.isnan(df.Survived) == False]
df = df[np.isnan(df.Pclass) == False]
df = df[np.isnan(df.Age) == False]
df = df[np.isnan(df.Fare) == False]

# %%
df['Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
# 6        male
# 7        male
# 8      female
# 9      female
# 10     female
# 11     female
# 12       male
# 13       male
# 14     female
# 15     female
# 16       male
# 18     female
# 20       male
# 21       male
# 22     female
# 23       male
# 24     female
# 25     female
# 27       male
# 30       male
# 33       male
# 34       male
# 35       male
# 37       male
# 38     female
#         ...
# 856    female
# 857      male
# 858    female
# 860      male
# 861      male
# 862    female
# 864      male
# 865    female
# 866    female
# 867      male
# 869      male
# 870      male
# 871    female
# 872      male
# 873      male
# 874    female
# 875    female
# 876      male
# 877      male
# 879    female
# 880    female
# 881      male
# 882    female
# 883      male
# 884      male
# 885    female
# 886      male
# 887    female
# 889      male
# 890      male
# ...

# %%
X = df[['Pclass', 'Sex', 'Age', 'Fare']]
y = df[['Survived']]

# %%
sex_mapping = {'male': 0, 'female': 1}
X['Sex'] = map(lambda x: sex_mapping[x], X['Sex'])
# Out:
# /home/ishalyminov/.virtualenvs/coursera_vorontsov/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
clf = DecisionTreeClassifier(random_state=241)
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=241, splitter='best')

# %%
importances = clf.feature_importances_
print X.columns
print importances
with open('task_1', 'w') as task_1_out:
    task_1_out.write(' '.join(map(itemgetter(1), sorted(zip(importances, X.columns), reverse=True)[:2])))
# Out:
# Index([u'Pclass', u'Sex', u'Age', u'Fare'], dtype='object')
# [ 0.14751816  0.30051221  0.25124241  0.30072722]
